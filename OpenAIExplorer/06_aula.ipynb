# %%
import os

OPENAI_API_KEY = os.getenv("MYOPENAI_API_KEY")

import openai

# %%
client = openai.Client(api_key=OPENAI_API_KEY)

# %%
mensagens = [{'role': 'user', 'content': 'crie uma história sobre uma viagem a marte'}]

resposta = client.chat.completions.create(
    messages=mensagens,
    model='gpt-3.5-turbo-0125',
    max_tokens=1000,
    temperature=0,
    stream=True
)

# %%
resposta_completa = ''
for stream_resposta in resposta:
    texto = stream_resposta.choices[0].delta.content
    if texto:
        resposta_completa += texto
        print(texto, end='')
# Out:
# Era o ano de 2050 e a humanidade finalmente havia conseguido desenvolver a tecnologia necessária para realizar viagens interplanetárias. Um grupo de cientistas e astronautas estava se preparando para a primeira viagem tripulada a Marte.
#
# A nave espacial estava pronta e a tripulação embarcou ansiosa para a jornada de meses até o Planeta Vermelho. Durante a viagem, eles enfrentaram diversos desafios, como tempestades solares e problemas técnicos na nave, mas conseguiram superar tudo com determinação e trabalho em equipe.
#
# Finalmente, após meses de viagem, a nave chegou a Marte. A tripulação ficou maravilhada ao ver a paisagem árida e vermelha do planeta, com suas montanhas e vales impressionantes. Eles desembarcaram na superfície e começaram a explorar, coletando amostras de solo e rochas para estudar.
#
# Enquanto exploravam, a tripulação descobriu vestígios de vida antiga em Marte, o que os deixou ainda mais fascinados. Eles passaram dias estudando esses vestígios e fazendo descobertas incríveis que poderiam mudar para sempre nossa compreensão do universo.
#
# Após semanas de exploração, a tripulação finalmente se preparou para retornar à Terra. Eles deixaram Marte com o coração cheio de emoção e gratidão por terem tido a oportunidade de realizar essa incrível jornada.
#
# Ao retornarem à Terra, foram recebidos como heróis e suas descobertas foram aclamadas pela comunidade científica. A viagem a Marte havia sido um sucesso e abriu as portas para futuras explorações interplanetárias, mostrando que o ser humano é capaz de alcançar o impossível quando trabalha em conjunto.

# %%
print(resposta_completa)
# Out:
# Era o ano de 2050 e a humanidade finalmente havia conseguido desenvolver a tecnologia necessária para realizar viagens interplanetárias. Um grupo de cientistas e astronautas estava se preparando para a primeira viagem tripulada a Marte.
#
# A nave espacial estava pronta e a tripulação embarcou ansiosa para a jornada de meses até o Planeta Vermelho. Durante a viagem, eles enfrentaram diversos desafios, como tempestades solares e problemas técnicos na nave, mas conseguiram superar tudo com determinação e trabalho em equipe.
#
# Finalmente, após meses de viagem, a nave chegou a Marte. A tripulação ficou maravilhada ao ver a paisagem árida e vermelha do planeta, com suas montanhas e vales impressionantes. Eles desembarcaram na superfície e começaram a explorar, coletando amostras de solo e rochas para estudar.
#
# Enquanto exploravam, a tripulação descobriu vestígios de vida antiga em Marte, o que os deixou ainda mais fascinados. Eles passaram dias estudando esses vestígios e fazendo descobertas incríveis que poderiam mudar para sempre nossa compreensão do universo.
#
# Após semanas de exploração, a tripulação finalmente se preparou para retornar à Terra. Eles deixaram Marte com o coração cheio de emoção e gratidão por terem tido a oportunidade de realizar essa incrível jornada.
#
# Ao retornarem à Terra, foram recebidos como heróis e suas descobertas foram aclamadas pela comunidade científica. A viagem a Marte havia sido um sucesso e abriu as portas para futuras explorações interplanetárias, mostrando que o ser humano é capaz de alcançar o impossível quando trabalha em conjunto.
