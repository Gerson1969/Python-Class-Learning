# %%
import os

OPENAI_API_KEY = os.getenv("MYOPENAI_API_KEY")

import openai

# %%
client = openai.Client(api_key=OPENAI_API_KEY)

# %%
mensagens = [{'role': 'user', 'content': 'O que é uma maçã em 5 palavras?'}]

resposta = client.chat.completions.create(
    messages=mensagens,
    model='gpt-3.5-turbo-0125',
    max_tokens=1000,
    temperature=0
)

# %%
print(resposta.choices[0].message.content)
# Out:
# Fruta redonda e saborosa.

# %%
mensagens.append({'role': 'user', 'content': 'E qual é a sua cor?'})
# Out:
# Fruta redonda e saborosa.

# %%
mensagens.append({'role': 'assistant', 'content': resposta.choices[0].message.content})

# %%
mensagens.append({'role': 'user', 'content': 'E qual é a sua cor?'})

# %%
mensagens
# Out:
# [{'role': 'user', 'content': 'O que é uma maçã em 5 palavras?'},
#  {'content': 'Fruta redonda e saborosa.',
#   'role': 'assistant',
#   'annotations': []},
#  {'role': 'user', 'content': 'E qual é a sua cor?'},
#  {'content': 'Vermelha ou verde, dependendo da variedade.',
#   'role': 'assistant',
#   'annotations': []},
#  {'role': 'user', 'content': 'E qual é a sua cor?'},
#  {'content': 'Vermelha ou verde, dependendo da variedade.',
#   'role': 'assistant',
#   'annotations': []}]

# %%
resposta = client.chat.completions.create(
    messages=mensagens,
    model='gpt-3.5-turbo-0125',
    max_tokens=1000,
    temperature=0
)

# %%
print(resposta.choices[0].message.content)
# Out:
# Vermelha ou verde, dependendo da variedade.

# %% [markdown]
# ## Adicionando a uma função

# %%
def geracao_texto(mensagens, model='gpt-3.5-turbo-0125', max_tokens=1000, temperature=0):
    resposta = client.chat.completions.create(
        messages=mensagens,
        model=model,
        max_tokens=max_tokens,
        temperature=temperature
    )
    print(resposta.choices[0].message.content)
    mensagens.append(resposta.choices[0].message.model_dump(exclude_none=True))
    return mensagens

# %%
mensagens = [{'role': 'user', 'content': 'O que é uma maçã em 5 palavras?'}]
mensagens = geracao_texto(mensagens)
# Out:
# Fruta redonda e saborosa.

# %%
mensagens.append({'role': 'user', 'content': 'E qual é a sua cor?'})
mensagens = geracao_texto(mensagens)
# Out:
# Vermelha ou verde, dependendo da variedade.

# %% [markdown]
# ## Explorando classe de resposta

# %%
resposta = client.chat.completions.create(
    messages=mensagens,
    model='gpt-3.5-turbo-0125',
    max_tokens=1000,
    temperature=0
)

# %%
resposta.usage
# Out:
# CompletionUsage(completion_tokens=13, prompt_tokens=89, total_tokens=102, prompt_tokens_details={'cached_tokens': 0, 'audio_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0})

# %%
resposta.choices[0].message
# Out:
# ChatCompletionMessage(content='Vermelha ou verde, dependendo da variedidade.', role='assistant', function_call=None, tool_calls=None, refusal=None, annotations=[])

# %%
resposta.choices[0].message.model_dump(exclude_none=True)
# Out:
# {'content': 'Vermelha ou verde, dependendo da variedidade.',
#  'role': 'assistant',
#  'annotations': []}

# %% [markdown]
# ## Explorando max_tokens e temperature

# %%
mensagens = [{'role': 'user', 'content': 'O que é uma maçã em 5 palavras?'}]
mensagens = geracao_texto(mensagens, max_tokens=3)
# Out:
# Fruta red

# %%
mensagens = [{'role': 'user', 'content': 'O que é uma maçã?'}]
mensagens = geracao_texto(mensagens, temperature=1)
# Out:
# Uma maçã é uma fruta redonda, geralmente de cor vermelha ou verde, comestível e com casca fina. É uma das frutas mais populares e consumidas em todo o mundo, sendo rica em vitaminas, fibras e antioxidantes. Ela pode ser consumida crua, em sucos, cozida em compotas, assada em sobremesas, entre outras formas.
